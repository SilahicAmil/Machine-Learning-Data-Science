# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
ppp = pd.read_csv("PPP_data_150k_plus.csv")

# %%
ppp
# Out:
#                  LoanRange                           BusinessName  \
# 0          a $5-10 million  ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1          a $5-10 million                  CRUZ CONSTRUCTION INC
# 2          a $5-10 million                 I. C. E. SERVICES, INC
# 3          a $5-10 million             KATMAI HEALTH SERVICES LLC
# 4          a $5-10 million        MATANUSKA TELEPHONE ASSOCIATION
# ...                    ...                                    ...
# 661213  e $150,000-350,000                          NOT AVAILABLE
# 661214  e $150,000-350,000                          NOT AVAILABLE
# 661215  e $150,000-350,000                          NOT AVAILABLE
# 661216  e $150,000-350,000                 OTTAWA PRODUCTS CO INC
# 661217  e $150,000-350,000                         POPPYCOCKS INC
#
#                                        Address       City State      Zip  \
# 0                                 7000 Uula St     BARROW    AK  99723.0
# ...

# %%
plt.figure(figsize=(30,15))
# plt.title('Jobs Retained')
pppdata = ppp.pivot_table(values='JobsRetained',index='BusinessType',columns='State')
# sns.heatmap(pppbid)
# pppdata = ppp.pivot_table(values="NAICSCode",index="JobsRetained",columns="BusinessType")
pppData = pppdata.dropna()
sns.set_context('paper',font_scale=2)
sns.barplot(data=pppData,palette='coolwarm') 
plt.ylabel("Jobs Retained")
plt.xticks(rotation=30)
plt.tight_layout()

# %%
sns.barplot(data=pppData,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
sns.set_theme(style="ticks")
mpg = pd.read_csv("PPP_data_150k_plus.csv")

colors = (250, 70, 50), (350, 70, 50)
cmap = sns.blend_palette(colors, input="husl", as_cmap=True)
sns.displot(
    mpg,
    x="State",
    kind="ecdf", aspect=.75, linewidth=2, palette=cmap,
)

# %%
sns.violinplot(data=pppData)
# Out:
# <AxesSubplot:xlabel='State'>

# %%
plt.figure(figsize=(30,15))
values = ppp.pivot_table(values='JobsRetained',index='DateApproved')
pppValues = values.dropna()
pppValues.mean()
pppDates = pd.date_range("4/14/2020", end="6/30/2020",freq="D")
# pppData2 = pd.DataFrame(pppValues,pppDates,columns=["A" , "B" , "C" , "D"])
sns.set_context('paper',font_scale=.6)
plt.xticks(rotation=30)
sns.set(style="whitegrid")
sns.lineplot(x="DateApproved",y="JobsRetained", data=pppValues)
# plt.savefig("LinePlot.jpg", dpi=300)
# Out:
# <AxesSubplot:xlabel='DateApproved', ylabel='JobsRetained'>

# %%
plt.figure(figsize=(30,15))
values = ppp.pivot_table(values='JobsRetained',index='Lender',columns='BusinessType')
pppValues = values.dropna()
# pppDates = pd.date_range("4/14/2020",periods=365,freq="D")
# pppData2 = pd.DataFrame(pppValues,pppDates,columns=["A" , "B" , "C" , "D"])
sns.set_context('paper',font_scale=1)
sns.barplot(data = pppValues)
